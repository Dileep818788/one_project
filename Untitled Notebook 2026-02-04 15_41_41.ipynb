-- %%
%python


player_name = input("Enter the player's name: ")

games_played = int(input("Enter the number of games played: "))

total_score = int(input("Enter the total score achieved: "))

average_score = total_score / games_played

print("\nPlayer:", player_name)
print("Games Played:", games_played)
print("Total Score:", total_score)
print("Average Score:", average_score)
-- Out:
-- Enter the player's name:  dileep
-- Enter the number of games played:  15
-- Enter the total score achieved:  85
-- Player: dileep
-- Games Played: 15
-- Total Score: 85
-- Average Score: 5.666666666666667
